# %%
# use fout.write(f"...") to save the data 
def exp_expansion(x, N, fname):
    """Add docs here"""
    total = 0.0
    fout = open(fname, "w")
    
    for ii in range(0, N+1):
        total+=((-x)**(ii))/factorial(ii)
        fout.write(f"%010d \t %.16f \n"%(ii, total))
        
    fout.close()

def factorial(n):
    """Add docs here"""
    result = 1.0
    for ii in range(1,n+1):
        result *= ii
    return result
 
# Call the function  
exp_expansion(x=1.8766, N=10000, fname="sumdata.txt")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[4], line 21
#      18     return result
#      20 # Call the function
# ---> 21 exp_expansion(x=1.8766, N=10000, fname="sumdata.txt")
#
# Cell In[4], line 8, in exp_expansion(x, N, fname)
#       5 fout = open(fname, "w")
#       7 for ii in range(0, N+1):
# ----> 8     total+=((-x)**(ii))/factorial(ii)
#       9     fout.write(f"%010d \t %.16f \n"%(ii, total))
#      11 fout.close()
#
# OverflowError: (34, 'Numerical result out of range')

# %%
# %matplotlib inline
# Plot the data

import matplotlib.pyplot as plt
import numpy as np
x, y = np.loadtxt('sumdata.txt', unpack = True)
plt.plot(x, y, 'ro')

# %%
# use fout.write(f"...") to save the data 
def exp_expansion_new(x, N, fname):
    """Add docs here"""
    total = 0.0
    a_i = 1.0
    total2 = 0.0
    fout = open(fname, "w")
    for ii in range(0, N+1):
        total+=((-x)**(ii))/factorial(ii)
        total2 += a_i
        a_i*=(-x)/(ii+1)
        fout.write(f"%010d \t %.16f \t %.16f \n"%(ii, total, total2))
    fout.close()

# Call the NEW function  
exp_expansion_new(x=1.8766, N=10000, fname="sumdatanew.txt")
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[14], line 16
#      13     fout.close()
#      15 # Call the NEW function
# ---> 16 exp_expansion_new(x=1.8766, N=10000, fname="sumdatanew.txt")
#
# Cell In[14], line 9, in exp_expansion_new(x, N, fname)
#       7 fout = open(fname, "w")
#       8 for ii in range(0, N+1):
# ----> 9     total+=((-x)**(ii))/factorial(ii)
#      10     total2 += a_i
#      11     a_i*=(-x)/(ii+1)
#
# OverflowError: (34, 'Numerical result out of range')

# %%
# %matplotlib inline
# Plot the data

import matplotlib.pyplot as plt
import numpy as np
x, y, z = np.loadtxt('sumdatanew.txt', unpack = True)
plt.plot(x, y, 'ro')
plt.plot(x, z, 'b-')

plt.show()

# %% [markdown]
# - Óscar Azula
# - Jose Chávez
# - Andrés Portela
# - Juan Sierra
# - Cristhian Casas.
